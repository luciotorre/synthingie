# %%
from synthingie import Module

# %% [markdown]
# Define synth parameters

# %%
SAMPLERATE = 44100
FRAMESIZE = 441

# %% [markdown]
# Create a synth module

# %%
mod = Module(SAMPLERATE, FRAMESIZE)

# %% [markdown]
# Add a sin operation

# %%
sin = mod.sin(440)

# %% [markdown]
# Generate the output

# %%
audio = mod.render(sin, duration_s=10)

# %% [markdown]
# Lets look at it

# %%
audio.display(limit_samples=1000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Make a sin modulated by a sin

# %%
mod = Module(SAMPLERATE, FRAMESIZE)
sin = mod.sin(mod.sin(2) * 100 + 440)
audio = mod.render(sin, duration_s=10)

# %%
audio.display(limit_samples=1000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
